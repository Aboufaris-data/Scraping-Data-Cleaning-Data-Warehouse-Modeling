# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\user\Desktop\Scraping, Data Cleaning & Data Warehouse Modeling\data\avito_data_clean.csv")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     380 non-null    str
#  1   price     380 non-null    int64
#  2   location  380 non-null    str
#  3   surface   332 non-null    str
#  4   rooms     380 non-null    str
#  5   baths     380 non-null    str
#  6   link      380 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 20.9 KB

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df["surface"] = df["surface"].str.extract(r'(\d+)')[0].astype(float).astype("Int64")

# %%
df["rooms"] = df["rooms"].str.replace(r"chambres|chambre", "", regex=True).str.strip().astype(int)

# %%
df["baths"] = df["baths"].str.replace(r"sdbs|sdb", "", regex=True).str.strip().astype(int)

# %%
df["ville"] = df["location"].str.replace("Appartements dans", "").str.split(",").str[0].str.strip()

# %%
df["quartier"] =  df["location"].str.replace("Appartements dans", "").str.split(",").str[1].str.strip()

# %%
df["quartier"].unique()
# Out:
# array(['Toute la ville', 'Hay Mohammadi', 'Bachkou', 'Palmier',
#        'Hivernage', 'Autre secteur', 'Quartier des Hôpitaux', 'Maarif',
#        'Sidi Maarouf', 'Almaz', 'Semlalia', 'Racine', "M'Hamid",
#        'Bourgogne', 'Maârif Extension', '2 Mars', 'Guéliz', 'Victoria',
#        'Aïn Chock', 'Quartier du Parc', 'Californie', 'Beauséjour',
#        'Val Fleuri', 'Hay Hassani', 'Malabata', 'Gauthier', 'Du Golf',
#        'Mabrouka', 'Said Hajji', 'Ziatene', 'Sala El Jadida', 'Founty',
#        'Anfa', 'Belvédère', 'Targa', 'El Houda', 'Hay Izdihar',
#        'Victor Hugo', 'Azzouzia', 'Hay Salam', 'Av Abdelkrim El Khattabi',
#        "Triangle d'Or", 'Bir Rami', 'Roches Noires', 'Ain Sebaa', 'Oasis',
#        'Wifak', 'Marina', 'Harhoura', 'Casablanca Finance City',
#        'Sidi Othmane', 'Ville Nouvelle', 'Riviera', 'Route de Casablanca',
#        'Hay Essalam', 'Mimosas', 'Sidi Bernoussi', 'Aïn Borja', 'Aida',
#        'Corniche', 'Centre Ville', 'Centre ville', 'Tanja Balia', 'Oulfa',
#        'Anza', 'Abdelmoumen', 'Av Mokawama', 'Massira 1', 'Route de Safi',
#        'Administratif', 'Palmeraie', 'Les Princesses', 'Castilla',
#        'Iberie', "Ben M'sick", 'Errahma', 'Mers Sultan', 'Lissasfa',
#        'Al Fida', 'Centre', 'Hay Riad', 'Marjane', 'El Bassatine',
#        'Guich Oudaya', 'Safir', 'Wislane', 'Hamria', 'Al Boustane',
#        'Souissi', 'Agdal', 'Ouled Oujih', 'Les Portes de Marrakech',
#        'Ain Atig', 'Tanger City Center', 'Seyad', 'Tamraght',
#        'Hay Moulay Rachid', 'alliance', 'Achakar', 'Skikina', 'Sania',
#        'Champ de course', 'Hay Charaf', 'Haut-Founty'], dtype=object)

# %%
df["title"] = (df["title"].str.encode("ascii", "ignore").str.decode("ascii").str.replace(r"\s+", " ", regex=True).str.strip())

# %%
df["price"].describe()
# Out:
# count    3.190000e+02
# mean     3.389575e+06
# std      3.703011e+07
# min      1.500000e+05
# 25%      6.917500e+05
# 50%      1.077000e+06
# 75%      1.645000e+06
# max      6.624512e+08
# Name: price, dtype: float64

# %%
df["ville"] = df["ville"].str.title().str.strip()
df["quartier"] = df["quartier"].str.title().str.strip()

# %%
df.to_csv("avito_pp.csv", index=False)
